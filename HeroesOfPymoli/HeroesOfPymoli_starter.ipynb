# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %%
#Verified data is complete
purchase_data.count()
# Out:
# Purchase ID    780
# SN             780
# Age            780
# Gender         780
# Item ID        780
# Item Name      780
# Price          780
# dtype: int64

# %%
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
playerCount = purchase_data["SN"].nunique()
playerCount_df = pd.DataFrame({
    "Total Players" : [playerCount]
})

#Formating
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', '#F7F5FB'),
  ('background-color', '#324A5F')
  ]

td_props = [
  ('font-size', '13px'),
    ('text-align', 'center')
  ]

styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]


(playerCount_df.style
    .set_table_styles(styles))
# Out:
# <style  type="text/css" >
#     #T_836f9688_836f_11ea_9ad5_f40f24102861 th {
#           font-size: 14px;
#           text-align: center;
#           font-weight: bold;
#           color: #F7F5FB;
#           background-color: #324A5F;
#     }    #T_836f9688_836f_11ea_9ad5_f40f24102861 td {
#           font-size: 13px;
#           text-align: center;
#     }</style><table id="T_836f9688_836f_11ea_9ad5_f40f24102861" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_836f9688_836f_11ea_9ad5_f40f24102861level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_836f9688_836f_11ea_9ad5_f40f24102861row0_col0" class="data row0 col0" >576</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Introduciong data into a df

purchasingAnalysis_df = pd.DataFrame({
    "Number of Unique Items" : purchase_data["Item Name"].nunique(),
    "Average Price" : [purchase_data["Price"].mean()],
    "Number of Purchases" : purchase_data["Purchase ID"].nunique(),
    "Total Revenue" : [purchase_data["Price"].sum()]
})


#Formating
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', '#F7F5FB'),
  ('background-color', '#324A5F')
  ]

td_props = [
  ('font-size', '13px'),
    ('text-align', 'center')
  ]

styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]


(purchasingAnalysis_df.style
    .format({'Average Price': "${:.2f}"})
     .format({'Total Revenue': "${:.2f}"})
    .set_table_styles(styles))
# Out:
# <style  type="text/css" >
#     #T_86fc080e_836f_11ea_9ad5_f40f24102861 th {
#           font-size: 14px;
#           text-align: center;
#           font-weight: bold;
#           color: #F7F5FB;
#           background-color: #324A5F;
#     }    #T_86fc080e_836f_11ea_9ad5_f40f24102861 td {
#           font-size: 13px;
#           text-align: center;
#     }</style><table id="T_86fc080e_836f_11ea_9ad5_f40f24102861" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Unique Items</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Number of Purchases</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_86fc080e_836f_11ea_9ad5_f40f24102861level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_86fc080e_836f_11ea_9ad5_f40f24102861row0_col0" class="data row0 col0" >179</td>
#                         <td id="T_86fc080e_836f_11ea_9ad5_f40f24102861row0_col1" class="data row0 col1" >$3.05</td>
#                         <td id="T_86fc080e_836f_11ea_9ad5_f40f24102861row0_col2" class="data row0 col2" >780</td>
#                         <td id="T_86fc080e_836f_11ea_9ad5_f40f24102861row0_col3" class="data row0 col3" >$2379.77</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
#Eliminating duplicates
purchase_data_df = pd.DataFrame(purchase_data)
purchase_data_df_nd = purchase_data.drop_duplicates(subset = "SN")

#Creating DF
gender_dem_df = pd.DataFrame ({
    "Total Count" : purchase_data_df_nd["Gender"].value_counts(),
    "Percentage of Players" : purchase_data_df_nd["Gender"].value_counts() * 100 / playerCount

})

#Formating
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', '#F7F5FB'),
  ('background-color', '#324A5F')
  ]

td_props = [
  ('font-size', '13px'),
    ('text-align', 'center')
  ]

styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]


(gender_dem_df.style
    .format({'Percentage of Players': "{:.2f}%"})
    .set_table_styles(styles))
# Out:
# <style  type="text/css" >
#     #T_8f3d2cc8_836f_11ea_9ad5_f40f24102861 th {
#           font-size: 14px;
#           text-align: center;
#           font-weight: bold;
#           color: #F7F5FB;
#           background-color: #324A5F;
#     }    #T_8f3d2cc8_836f_11ea_9ad5_f40f24102861 td {
#           font-size: 13px;
#           text-align: center;
#     }</style><table id="T_8f3d2cc8_836f_11ea_9ad5_f40f24102861" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8f3d2cc8_836f_11ea_9ad5_f40f24102861level0_row0" class="row_heading level0 row0" >Male</th>
#                         <td id="T_8f3d2cc8_836f_11ea_9ad5_f40f24102861row0_col0" class="data row0 col0" >484</td>
#                         <td id="T_8f3d2cc8_836f_11ea_9ad5_f40f24102861row0_col1" class="data row0 col1" >84.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3d2cc8_836f_11ea_9ad5_f40f24102861level0_row1" class="row_heading level0 row1" >Female</th>
#                         <td id="T_8f3d2cc8_836f_11ea_9ad5_f40f24102861row1_col0" class="data row1 col0" >81</td>
#                         <td id="T_8f3d2cc8_836f_11ea_9ad5_f40f24102861row1_col1" class="data row1 col1" >14.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_8f3d2cc8_836f_11ea_9ad5_f40f24102861level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_8f3d2cc8_836f_11ea_9ad5_f40f24102861row2_col0" class="data row2 col0" >11</td>
#                         <td id="T_8f3d2cc8_836f_11ea_9ad5_f40f24102861row2_col1" class="data row2 col1" >1.91%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Filtering DF for male users
maleF = purchase_data_df["Gender"] == "Male"
purchase_data_male = purchase_data_df.loc[maleF]

countM = purchase_data_male["Purchase ID"].count()
meanM = purchase_data_male["Price"].mean()
sumM = purchase_data_male["Price"].sum()
avgpurM = sumM/gender_nd["Male"]

#Filtering DF for female users
femaleF = purchase_data_df["Gender"] == "Female"
purchase_data_female = purchase_data_df.loc[femaleF]

countF = purchase_data_female["Purchase ID"].count()
meanF = purchase_data_female["Price"].mean()
sumF = purchase_data_female["Price"].sum()
avgpurF = sumF/gender_nd["Female"]

#Filtering DF for other users
otherF = purchase_data_df["Gender"] == "Other / Non-Disclosed"
purchase_data_other = purchase_data_df.loc[otherF]

countO = purchase_data_other["Purchase ID"].count()
meanO = purchase_data_other["Price"].mean()
sumO = purchase_data_other["Price"].sum()
avgpurO = sumO/gender_nd["Other / Non-Disclosed"]


#Creating DF (Maintained MFO order for consistency)
purchasing_analysis_g_df = pd.DataFrame ({
    "Gender" : ["Male", "Female", "Other / Non-Disclosed"],
    "Purchase Count" : [countM, countF, countO],
    "Average Purchase Price" : [meanM, meanF, meanO],
    "Total Purchase Value" : [sumM, sumF, sumO],
    "Avg Total Purchase per Person" : [avgpurM, avgpurF, avgpurO]
    
})

purchasing_analysis_g_df = purchasing_analysis_g_df.set_index("Gender")

#Formating
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', '#F7F5FB'),
  ('background-color', '#324A5F')
  ]

td_props = [
  ('font-size', '13px'),
    ('text-align', 'center')
  ]

styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]


(purchasing_analysis_g_df.style
    .format({'Average Purchase Price': "${:.2f}"})
    .format({'Total Purchase Value': "${:,.2f}"})
    .format({'Avg Total Purchase per Person': "${:,.2f}"})
    .set_table_styles(styles))
# Out:
# <style  type="text/css" >
#     #T_4b7b6c22_8372_11ea_9ad5_f40f24102861 th {
#           font-size: 14px;
#           text-align: center;
#           font-weight: bold;
#           color: #F7F5FB;
#           background-color: #324A5F;
#     }    #T_4b7b6c22_8372_11ea_9ad5_f40f24102861 td {
#           font-size: 13px;
#           text-align: center;
#     }</style><table id="T_4b7b6c22_8372_11ea_9ad5_f40f24102861" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase per Person</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4b7b6c22_8372_11ea_9ad5_f40f24102861level0_row0" class="row_heading level0 row0" >Male</th>
#                         <td id="T_4b7b6c22_8372_11ea_9ad5_f40f24102861row0_col0" class="data row0 col0" >652</td>
#                         <td id="T_4b7b6c22_8372_11ea_9ad5_f40f24102861row0_col1" class="data row0 col1" >$3.02</td>
#                         <td id="T_4b7b6c22_8372_11ea_9ad5_f40f24102861row0_col2" class="data row0 col2" >$1,967.64</td>
#                         <td id="T_4b7b6c22_8372_11ea_9ad5_f40f24102861row0_col3" class="data row0 col3" >$4.07</td>
#             </tr>
#             <tr>
#                         <th id="T_4b7b6c22_8372_11ea_9ad5_f40f24102861level0_row1" class="row_heading level0 row1" >Female</th>
#                         <td id="T_4b7b6c22_8372_11ea_9ad5_f40f24102861row1_col0" class="data row1 col0" >113</td>
#                         <td id="T_4b7b6c22_8372_11ea_9ad5_f40f24102861row1_col1" class="data row1 col1" >$3.20</td>
#                         <td id="T_4b7b6c22_8372_11ea_9ad5_f40f24102861row1_col2" class="data row1 col2" >$361.94</td>
#                         <td id="T_4b7b6c22_8372_11ea_9ad5_f40f24102861row1_col3" class="data row1 col3" >$4.47</td>
#             </tr>
#             <tr>
#                         <th id="T_4b7b6c22_8372_11ea_9ad5_f40f24102861level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_4b7b6c22_8372_11ea_9ad5_f40f24102861row2_col0" class="data row2 col0" >15</td>
#                         <td id="T_4b7b6c22_8372_11ea_9ad5_f40f24102861row2_col1" class="data row2 col1" >$3.35</td>
#                         <td id="T_4b7b6c22_8372_11ea_9ad5_f40f24102861row2_col2" class="data row2 col2" >$50.19</td>
#                         <td id="T_4b7b6c22_8372_11ea_9ad5_f40f24102861row2_col3" class="data row2 col3" >$4.56</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
bins =[0, 9, 14, 19, 24, 29, 34, 39, 99]

labels = ["<10","10-14","15-19", "20-24", "25-29", "30-34", "35-39",
         "40+"]

purchase_data_df_nd["Age Ranges"] = pd.cut(
    purchase_data_df_nd["Age"],
    bins,
    labels=labels)

purchase_data_male_nd = purchase_data_df_nd.loc[maleF]
purchase_data_female_nd = purchase_data_df_nd.loc[femaleF]

summary_demo_df = pd.DataFrame({
    
    "Total Count" : purchase_data_df_nd.groupby(
        "Age Ranges")["Age"].count(),
    "Percentage of Players": purchase_data_df_nd.groupby(
        "Age Ranges")["Age"].count() / playerCount * 100,
    "Males" : purchase_data_male_nd.groupby(
        "Age Ranges")["Age"].count(),
    "Females" : purchase_data_female_nd.groupby(
        "Age Ranges")["Age"].count()
    
})
#Formating
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', '#F7F5FB'),
  ('background-color', '#324A5F')
  ]

td_props = [
  ('font-size', '13px'),
    ('text-align', 'center')
  ]

styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]


(summary_demo_df.style
    .format({'Percentage of Players': "{:.2f}%"})
    .set_table_styles(styles))
# Out:
# /Users/fer/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# <style  type="text/css" >
#     #T_aa7dc706_8372_11ea_9ad5_f40f24102861 th {
#           font-size: 14px;
#           text-align: center;
#           font-weight: bold;
#           color: #F7F5FB;
#           background-color: #324A5F;
#     }    #T_aa7dc706_8372_11ea_9ad5_f40f24102861 td {
#           font-size: 13px;
#           text-align: center;
#     }</style><table id="T_aa7dc706_8372_11ea_9ad5_f40f24102861" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>        <th class="col_heading level0 col2" >Males</th>        <th class="col_heading level0 col3" >Females</th>    </tr>    <tr>        <th class="index_name level0" >Age Ranges</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aa7dc706_8372_11ea_9ad5_f40f24102861level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row0_col0" class="data row0 col0" >17</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row0_col1" class="data row0 col1" >2.95%</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row0_col2" class="data row0 col2" >13</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row0_col3" class="data row0 col3" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_aa7dc706_8372_11ea_9ad5_f40f24102861level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row1_col0" class="data row1 col0" >22</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row1_col1" class="data row1 col1" >3.82%</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row1_col2" class="data row1 col2" >19</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row1_col3" class="data row1 col3" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_aa7dc706_8372_11ea_9ad5_f40f24102861level0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row2_col0" class="data row2 col0" >107</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row2_col1" class="data row2 col1" >18.58%</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row2_col2" class="data row2 col2" >86</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row2_col3" class="data row2 col3" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_aa7dc706_8372_11ea_9ad5_f40f24102861level0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row3_col0" class="data row3 col0" >258</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row3_col1" class="data row3 col1" >44.79%</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row3_col2" class="data row3 col2" >214</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row3_col3" class="data row3 col3" >40</td>
#             </tr>
#             <tr>
#                         <th id="T_aa7dc706_8372_11ea_9ad5_f40f24102861level0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row4_col0" class="data row4 col0" >77</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row4_col1" class="data row4 col1" >13.37%</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row4_col2" class="data row4 col2" >68</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row4_col3" class="data row4 col3" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_aa7dc706_8372_11ea_9ad5_f40f24102861level0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row5_col0" class="data row5 col0" >52</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row5_col1" class="data row5 col1" >9.03%</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row5_col2" class="data row5 col2" >47</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row5_col3" class="data row5 col3" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_aa7dc706_8372_11ea_9ad5_f40f24102861level0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row6_col0" class="data row6 col0" >31</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row6_col1" class="data row6 col1" >5.38%</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row6_col2" class="data row6 col2" >26</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row6_col3" class="data row6 col3" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_aa7dc706_8372_11ea_9ad5_f40f24102861level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row7_col0" class="data row7 col0" >12</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row7_col1" class="data row7 col1" >2.08%</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row7_col2" class="data row7 col2" >11</td>
#                         <td id="T_aa7dc706_8372_11ea_9ad5_f40f24102861row7_col3" class="data row7 col3" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
bins =[0, 9, 14, 19, 24, 29, 34, 39, 99]

labels = ["<10","10-14","15-19", "20-24", "25-29", "30-34", "35-39",
         "40+"]

purchase_data_df["Age Ranges"] = pd.cut(
    purchase_data_df["Age"],
    bins,
    labels=labels)

summary_ages_df = pd.DataFrame({
    
    "Purchase Count": purchase_data_df.groupby(
    "Age Ranges")["Purchase ID"].count(),
    
    "Average Purchase Price": purchase_data_df.groupby(
    "Age Ranges")["Price"].mean(),
                                
    "Total Purchase Value" : purchase_data_df.groupby(
    "Age Ranges")["Price"].sum(),
    
    "Avg Total Purchase per Person" : summary_ages_df ["Total Purchase Value"] / age_summary ["Total Count"],
     
})

#Formating
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', '#F7F5FB'),
  ('background-color', '#324A5F')
  ]

td_props = [
  ('font-size', '13px'),
    ('text-align', 'center')
  ]

styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]


(summary_ages_df.style
    .format({'Average Purchase Price': "${:.2f}"})
    .format({'Total Purchase Value': "${:,.2f}"})
    .format({'Avg Total Purchase per Person': "${:.2f}"})
    .set_table_styles(styles))
# Out:
# <style  type="text/css" >
#     #T_cfd890ba_836f_11ea_9ad5_f40f24102861 th {
#           font-size: 14px;
#           text-align: center;
#           font-weight: bold;
#           color: #F7F5FB;
#           background-color: #324A5F;
#     }    #T_cfd890ba_836f_11ea_9ad5_f40f24102861 td {
#           font-size: 13px;
#           text-align: center;
#     }</style><table id="T_cfd890ba_836f_11ea_9ad5_f40f24102861" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase per Person</th>    </tr>    <tr>        <th class="index_name level0" >Age Ranges</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cfd890ba_836f_11ea_9ad5_f40f24102861level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row0_col0" class="data row0 col0" >23</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row0_col1" class="data row0 col1" >$3.35</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row0_col2" class="data row0 col2" >$77.13</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row0_col3" class="data row0 col3" >$4.54</td>
#             </tr>
#             <tr>
#                         <th id="T_cfd890ba_836f_11ea_9ad5_f40f24102861level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row1_col0" class="data row1 col0" >28</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row1_col1" class="data row1 col1" >$2.96</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row1_col2" class="data row1 col2" >$82.78</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row1_col3" class="data row1 col3" >$3.76</td>
#             </tr>
#             <tr>
#                         <th id="T_cfd890ba_836f_11ea_9ad5_f40f24102861level0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row2_col0" class="data row2 col0" >136</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row2_col1" class="data row2 col1" >$3.04</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row2_col2" class="data row2 col2" >$412.89</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row2_col3" class="data row2 col3" >$3.86</td>
#             </tr>
#             <tr>
#                         <th id="T_cfd890ba_836f_11ea_9ad5_f40f24102861level0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row3_col0" class="data row3 col0" >365</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row3_col1" class="data row3 col1" >$3.05</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row3_col2" class="data row3 col2" >$1,114.06</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row3_col3" class="data row3 col3" >$4.32</td>
#             </tr>
#             <tr>
#                         <th id="T_cfd890ba_836f_11ea_9ad5_f40f24102861level0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row4_col0" class="data row4 col0" >101</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row4_col1" class="data row4 col1" >$2.90</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row4_col2" class="data row4 col2" >$293.00</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row4_col3" class="data row4 col3" >$3.81</td>
#             </tr>
#             <tr>
#                         <th id="T_cfd890ba_836f_11ea_9ad5_f40f24102861level0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row5_col0" class="data row5 col0" >73</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row5_col1" class="data row5 col1" >$2.93</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row5_col2" class="data row5 col2" >$214.00</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row5_col3" class="data row5 col3" >$4.12</td>
#             </tr>
#             <tr>
#                         <th id="T_cfd890ba_836f_11ea_9ad5_f40f24102861level0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row6_col0" class="data row6 col0" >41</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row6_col1" class="data row6 col1" >$3.60</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row6_col2" class="data row6 col2" >$147.67</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row6_col3" class="data row6 col3" >$4.76</td>
#             </tr>
#             <tr>
#                         <th id="T_cfd890ba_836f_11ea_9ad5_f40f24102861level0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row7_col0" class="data row7 col0" >13</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row7_col1" class="data row7 col1" >$2.94</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row7_col2" class="data row7 col2" >$38.24</td>
#                         <td id="T_cfd890ba_836f_11ea_9ad5_f40f24102861row7_col3" class="data row7 col3" >$3.19</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# purchase_data_df["SN"].value_counts()

top_spenders_df = pd.DataFrame({
    "Purchase Count" : purchase_data_df.groupby("SN")["Purchase ID"].count(),
    "Average Purchase Price" : purchase_data_df.groupby("SN")["Price"].sum()  
    / purchase_data_df.groupby("SN")["Purchase ID"].count(),
    "Total Purchase Value" : purchase_data_df.groupby("SN")["Price"].sum(),
})


top_spenders_df = top_spenders_df.sort_values(ascending = False, by = "Total Purchase Value").head(5)


#Formating
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', '#F7F5FB'),
  ('background-color', '#324A5F')
  ]

td_props = [
  ('font-size', '13px'),
    ('text-align', 'center')
  ]

styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]


(top_spenders_df.style
    .format({'Average Purchase Price': "${:.2f}"})
    .format({'Total Purchase Value': "${:.2f}"})
    .set_table_styles(styles))
# Out:
# <style  type="text/css" >
#     #T_49572582_8366_11ea_9ad5_f40f24102861 th {
#           font-size: 14px;
#           text-align: center;
#           font-weight: bold;
#           color: #F7F5FB;
#           background-color: #324A5F;
#     }    #T_49572582_8366_11ea_9ad5_f40f24102861 td {
#           font-size: 13px;
#           text-align: center;
#     }</style><table id="T_49572582_8366_11ea_9ad5_f40f24102861" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_49572582_8366_11ea_9ad5_f40f24102861level0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_49572582_8366_11ea_9ad5_f40f24102861row0_col0" class="data row0 col0" >5</td>
#                         <td id="T_49572582_8366_11ea_9ad5_f40f24102861row0_col1" class="data row0 col1" >$3.79</td>
#                         <td id="T_49572582_8366_11ea_9ad5_f40f24102861row0_col2" class="data row0 col2" >$18.96</td>
#             </tr>
#             <tr>
#                         <th id="T_49572582_8366_11ea_9ad5_f40f24102861level0_row1" class="row_heading level0 row1" >Idastidru52</th>
#                         <td id="T_49572582_8366_11ea_9ad5_f40f24102861row1_col0" class="data row1 col0" >4</td>
#                         <td id="T_49572582_8366_11ea_9ad5_f40f24102861row1_col1" class="data row1 col1" >$3.86</td>
#                         <td id="T_49572582_8366_11ea_9ad5_f40f24102861row1_col2" class="data row1 col2" >$15.45</td>
#             </tr>
#             <tr>
#                         <th id="T_49572582_8366_11ea_9ad5_f40f24102861level0_row2" class="row_heading level0 row2" >Chamjask73</th>
#                         <td id="T_49572582_8366_11ea_9ad5_f40f24102861row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_49572582_8366_11ea_9ad5_f40f24102861row2_col1" class="data row2 col1" >$4.61</td>
#                         <td id="T_49572582_8366_11ea_9ad5_f40f24102861row2_col2" class="data row2 col2" >$13.83</td>
#             </tr>
#             <tr>
#                         <th id="T_49572582_8366_11ea_9ad5_f40f24102861level0_row3" class="row_heading level0 row3" >Iral74</th>
#                         <td id="T_49572582_8366_11ea_9ad5_f40f24102861row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_49572582_8366_11ea_9ad5_f40f24102861row3_col1" class="data row3 col1" >$3.40</td>
#                         <td id="T_49572582_8366_11ea_9ad5_f40f24102861row3_col2" class="data row3 col2" >$13.62</td>
#             </tr>
#             <tr>
#                         <th id="T_49572582_8366_11ea_9ad5_f40f24102861level0_row4" class="row_heading level0 row4" >Iskadarya95</th>
#                         <td id="T_49572582_8366_11ea_9ad5_f40f24102861row4_col0" class="data row4 col0" >3</td>
#                         <td id="T_49572582_8366_11ea_9ad5_f40f24102861row4_col1" class="data row4 col1" >$4.37</td>
#                         <td id="T_49572582_8366_11ea_9ad5_f40f24102861row4_col2" class="data row4 col2" >$13.10</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
top_items_df = pd.DataFrame({
    "Item Purchase Count" : purchase_data_df.groupby("Item ID"
                                          )["Item ID"].count(),
    "Total Purchase Value": purchase_data_df.groupby("Item ID")[
        "Price"].sum(),
    "Item Price" : purchase_data_df["Price"],
    "Item Name" : purchase_data_df["Item Name"],
    "Item ID" : purchase_data_df["Item ID"]
 })
top_items_df = top_items_df.sort_values(
    by = "Total Purchase Value", ascending = False)
top_items_df.head(93)
# Out:
#      Item Purchase Count  Total Purchase Value  Item Price  \
# 92                  13.0                 59.99        3.94
# 178                 12.0                 50.76        4.60
# 82                   9.0                 44.10        4.40
# 145                  9.0                 41.22        1.33
# 103                  8.0                 34.80        1.33
# 59                   8.0                 33.84        3.03
# 108                  9.0                 31.77        1.75
# 78                   7.0                 30.80        4.60
# 72                   8.0                 30.16        4.23
# 132                  9.0                 28.99        4.58
# 60                   8.0                 28.32        2.38
# 179                  6.0                 26.88        4.23
# 160                  6.0                 26.40        2.38
# 25                   6.0                 26.10        4.23
# 37                   8.0                 25.28        2.05
# 139                  5.0                 24.70        2.45
# 128                  5.0                 24.55        4.14
# 138                  5.0                 23.70        3.58
# 87                   5.0                 22.15        3.40
# 159                  7.0                 21.56        3.94
# 136                  6.0                 21.48        3.03
# 65                   5.0                 21.20        2.22
# 102                  6.0                 20.64        4.76
# 133                  5.0                 20.45        1.28
# 39                   5.0                 19.70        3.14
# 111                  4.0                 19.56        4.75
# 165                  4.0                 19.44        1.09
# 75                   8.0                 19.36        1.29
# 52                   4.0                 19.36        3.54
# 157                  4.0                 19.20        3.53
# ..                   ...                   ...         ...
# 140                  5.0                 14.70        3.93
# 64                   3.0                 14.46        2.92
# 98                   5.0                 14.45        3.19
# 167                  4.0                 14.44        4.80
# 53                   7.0                 14.35        2.84
# 109                  3.0                 14.28        1.16
# 150                  5.0                 14.25        1.28
# 41                   3.0                 14.25        1.33
# 95                   3.0                 14.22        1.63
# 16                   4.0                 14.20        2.52
# 94                   4.0                 13.96        3.09
# 89                   3.0                 13.92        1.70
# 174                  4.0                 13.88        1.94
# 67                   4.0                 13.84        4.74
# 175                  3.0                 13.44        4.35
# 162                  5.0                 13.35        1.66
# 83                   4.0                 13.32        1.02
# 22                   6.0                 13.08        3.81
# 119                  3.0                 12.96        4.43
# 76                   4.0                 12.60        3.75
# 172                  4.0                 12.56        4.24
# 74                   3.0                 12.54        4.64
# 117                  7.0                 12.53        1.79
# 85                   7.0                 12.25        1.16
# 79                   3.0                 12.15        2.96
# 105                  4.0                 12.12        1.79
# 182                  3.0                 12.09        4.40
# 148                  3.0                 12.09        4.03
# 44                   5.0                 11.90        2.73
# 93                   6.0                 11.82        3.75
#
#                                         Item Name  Item ID
# 92           Betrayal, Whisper of Grieving Widows       39
# 178               Despair, Favor of Due Diligence       57
# 82                                     Azurewrath      160
# 145                       Hopeless Ebon Dualblade       46
# 103                  Thorn, Satchel of Dark Souls        7
# 59                   Hailstorm Shadowsteel Scythe      105
# 108                                Malificent Bag       85
# 78                                           Dawn       50
# 72   Oathbreaker, Last Hope of the Breaking Storm      178
# 132                          Fiery Glass Crusader      145
# 60                          Bonecarvin Battle Axe       44
# 179                 Lightning, Etcher of the King       59
# 160                         Bonecarvin Battle Axe       44
# 25   Oathbreaker, Last Hope of the Breaking Storm      178
# 37                                    Ritual Mace       73
# 139            Darkheart, Butcher of the Champion      158
# 128             Freak's Bite, Favor of Holy Might       58
# 138                  Ghastly Adamantite Protector      136
# 87                                      Severance      151
# 159          Betrayal, Whisper of Grieving Widows       39
# 136                  Hailstorm Shadowsteel Scythe      105
# 65                                Retribution Axe       34
# 102              Downfall, Scalpel Of The Emperor      109
# 133                                      Splinter        0
# 39                             Blade of the Grave      172
# 111                                         Orbit       41
# 165                           Dragon's Greatsword      183
# 75                                 Venom Claymore      124
# 52                                           Wolf       60
# 157     Extraction, Quickblade Of Trembling Hands      108
# ..                                            ...      ...
# 140                      Purgatory, Gem of Regret        8
# 64                       Foul Titanium Battle Axe       56
# 98                                     Persuasion      132
# 167                       Spada, Etcher of Hatred      157
# 53                         Relentless Iron Skewer      176
# 109                                    Curved Axe       33
# 150                                      Splinter        0
# 41                   Thorn, Satchel of Dark Souls        7
# 95                               Exiled Doomblade      164
# 16                                  Second Chance       40
# 94                    Blood-Forged Skeletal Spine       96
# 89                   Lazarus, Terror of the Earth       17
# 174                        Blood Infused Guardian      144
# 67                 Peacekeeper, Wit of Dark Magic      138
# 175                                Singed Scalpel      103
# 162                                 Reaper's Toll      181
# 83                                          Dawne       12
# 22                                  Warped Fetish       24
# 119                      Deluge, Edge of the West       87
# 76               Emberling, Defender of Delusions       88
# 172                     Conqueror Adamantite Mace       65
# 74              Blazefury, Protector of Delusions       89
# 117             Heartstriker, Legacy of the Light      117
# 85                                     Curved Axe       33
# 79                           Soul Infused Crystal       15
# 105                                   Sleepwalker       10
# 182                                  Feral Katana      154
# 148            Warmonger, Gift of Suffering's End      148
# 44              Thorn, Conqueror of the Corrupted        9
# 93               Emberling, Defender of Delusions       88
#
# [93 rows x 5 columns]

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 103     Singed Scalpel                                            8
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# 92      Final Critic                                               $59.99
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 82      Nirvana                                                    $44.10
# 145     Fiery Glass Crusader                                       $41.22
# 103     Singed Scalpel                                             $34.80

# %% [markdown]
# # Observable Trends
# The total amount of players is 576
#
# The vast majority of our users are male in the 20 to 24 age range. (214 out of 484)
#
# Females are also mostly concentrated in the same age group. (40 out of 81)
#
# Even though males (4.07) account for a much bigger total purchase value, females (4.47) and others (4.56) have a higher avg purchase per person
#
# The age range with highest purchase per person is 35 to 39 years old (4.76), surprisingly it is followed by than 10 years old ($ 4.54).
#
# 64% of our total purchase value comes from ages 15 to 24. (1,526.95 of $ 2379.77)
#
# Our highest individual total purchase value comes from user Lisosia93 with a total of $18.96

# %%
# with pd.ExcelWriter('Resources/finalReport.xlsx') as writer:  

#     gender_dem_df.to_excel(
#         writer, sheet_name='Gender Demographics')

#     purchasing_analysis_g_df.to_excel(
#         writer, sheet_name='Purchasing Analysis (Gender)')
    
#     summary_demo_df.to_excel(
#         writer, sheet_name='Age Demographics')
    
#     summary_ages_df.to_excel(
#         writer, sheet_name='Purchasing Analysis (Age)')
    
#     top_spenders_df.to_excel(
#         writer, sheet_name='Top Spenders')
